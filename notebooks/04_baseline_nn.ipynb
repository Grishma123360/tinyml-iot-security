# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Dropout
import os

# 1. Setup matching parameters
num_classes = 3
timesteps = 64
num_channels = 5 

# 2. Build the uncompressed 1D-CNN Baseline Architecture
model = Sequential([
    Conv1D(16, 3, activation='relu', input_shape=(timesteps, num_channels)),
    MaxPooling1D(2),
    Conv1D(32, 3, activation='relu'),
    GlobalAveragePooling1D(),
    Dense(32, activation='relu'),
    Dropout(0.2), 
    Dense(num_classes, activation='softmax')
])

# 3. Compile the network
model.compile(
    optimizer='adam', 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

print("--- Baseline Deep Learning Architecture ---")
model.summary()

# 4. Train the model across 20 epochs using your preprocessed split variables
# Note: Ensure your '02_preprocessing.ipynb' arrays are available or re-imported here
print("\nTraining Baseline Neural Network...")
history = model.fit(
    X_train_scaled, y_train, 
    validation_data=(X_val_scaled, y_val), 
    epochs=20,
    batch_size=32
)

# 5. Save the uncompressed network to establish your "Before" baseline size
models_dir = r"C:\Users\ACER\tinyml-iot-security\models"
os.makedirs(models_dir, exist_ok=True)
uncompressed_path = os.path.join(models_dir, "baseline_nn_uncompressed.keras")
model.save(uncompressed_path)

file_size_kb = os.path.getsize(uncompressed_path) / 1024
print(f"\nSuccess! Uncompressed model saved file size: {file_size_kb:.2f} KB")
